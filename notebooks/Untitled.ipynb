# %%
import os
import pandas as pd
from src.process_data import process_data

# %%
fp = os.path.join('../data/ripc_rel.csv')
df = pd.read_csv(open(fp,mode='rb'),encoding='ISO-8859-1')

# %%
list(df.columns)
# Out:
# ['Name',
#  'Formula',
#  'Molecular Weight',
#  '1A',
#  '1B',
#  '1C',
#  '1D',
#  '1E',
#  '1F',
#  '1G',
#  '1H',
#  '1I',
#  '1J',
#  '1K',
#  '1L',
#  '2A',
#  '2B',
#  '2C',
#  '2D',
#  '2E',
#  '2F',
#  '2G',
#  '2H',
#  '2I',
#  '2J',
#  '2K',
#  '2L',
#  '2Platelet0',
#  '2Platelet1',
#  '2Platelet2',
#  '2Platelet3',
#  '2Platelet4',
#  '2Platelet5',
#  '2Platelet6',
#  '2Platelet7',
#  '2Platelet8',
#  '2Platelet9',
#  '2Platelet10',
#  '2Tech0',
#  '2Tech1',
#  '2Tech2',
#  '2Tech3',
#  '2Tech4',
#  '2Tech5',
#  '2Tech6',
#  '2Tech7',
#  '2Tech8',
#  '2Tech9',
#  '2Tech10',
#  '3A',
#  '3B',
#  '3C',
#  '3D',
#  '3E',
#  '3F',
#  '3G',
#  '3H',
#  '3I',
#  '3J',
#  '3K',
#  '3L',
#  '4A',
#  '4B',
#  '4C',
#  '4D',
#  '4E',
#  '4F',
#  '4G',
#  '4H',
#  '4I',
#  '4J (avg)',
#  '4K',
#  '4L',
#  '5A',
#  '5B',
#  '5C',
#  '5D',
#  '5E',
#  '5F',
#  '5G',
#  '5H',
#  '5I',
#  '5J',
#  '5K',
#  '5L',
#  '6A',
#  '6B',
#  '6C',
#  '6D',
#  '6E',
#  '6F',
#  '6G',
#  '6H',
# ...
