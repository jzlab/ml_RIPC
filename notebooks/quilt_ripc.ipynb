# %%
import os
import numpy as np
import pandas as pd

import quilt
from quilt.data.elijahc import ripc

# %%
quilt.inspect('elijahc/ripc')
# Out:
# /home/elijahc/.local/share/QuiltCli/quilt_packages/pkgs/Quilt/elijahc/ripc
# ├─┬ clustering
# │ ├── tsne_early_0_01: shape (22797, 7), types 'min': int64, 'Molecular_Weight': float64, 'log2fc_mean': float…
# │ ├── tsne_0_001: shape (18150, 7), types 'min': int64, 'Molecular_Weight': float64, 'log2fc_mean': float…
# │ ├── tsne_0_01: shape (26649, 6), types 'min': int64, 'Molecular_Weight': float64, 'dim_1': float64, 'd…
# │ ├── isomap_0_01: shape (26649, 6), types 'min': int64, 'Molecular_Weight': float64, 'dim_1': float64, 'd…
# │ ├── isomap_early_0_01: shape (22797, 7), types 'min': int64, 'Molecular_Weight': float64, 'log2fc_mean': float…
# │ └── tsne_0_05: shape (33282, 6), types 'min': int64, 'Molecular_Weight': float64, 'dim_1': float64, 'd…
# ├─┬ untargeted
# │ ├── log2fc_plasma: shape (71738, 302), types 'Molecular_Weight': float64, '10A': float64, '10B': float64, '1…
# ...

# %%
abs_q = ripc.targeted.abs_quant()
abs_q.head()
# Out:
#   Sample ID Sample type  Adenosine  N-N-Dimethylglycine  Glutathione  \
# 0        1A      Plasma   0.000000            14.415615          0.0
# 1        1B      Plasma   0.000000            22.488523          0.0
# 2        1C      Plasma   0.000000            14.507831          0.0
# 3        1D      Plasma   0.013192            18.304457          0.0
# 4        1E      Plasma   0.000000            16.413487          0.0
#
#    Kynurenine  Sphingosine 1-phosphate  Tryptophan  \
# 0    1.687163                 0.454013   53.538630
# 1    2.500635                 0.478104   64.356163
# 2    1.473818                 0.350754   41.354839
# 3    1.733681                 0.467263   49.381742
# 4    2.198124                 0.316195   52.727246
#
#    4-Hydroxy-2-quinolinecarboxylic acid  Hypoxanthine     ...       \
# 0                              0.037901     46.077182     ...
# 1                              0.052484     62.319556     ...
# ...
